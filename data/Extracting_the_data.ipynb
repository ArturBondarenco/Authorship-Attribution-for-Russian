# %% [markdown]
# I retrieved the data following the instructions provided at:
# https://www.kaggle.com/code/d0rj3228/authorship-attribution-for-russian-literature

# %% [markdown]
# ## Importing libraries, downloading punkt

# %%
from typing import List
import random

import glob
from nltk import tokenize, download
import numpy as np
import pandas as pd
download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ##Making lists of processed sentences per author

# %% [markdown]
# The split_text function should give us a list of sentences, the length of which is more than 5 characters, since shorter ones, most likely, do not carry information useful for attribution. To improve the performance of the offer tokenizer, some character combinations are replaced. So, the replicas will be separate from the speech of the author in sentences, and the problem with quotes should be solved.

# %%
def split_text(filepath: str, min_char: int = 5) -> List[str]:

    text = str()
    with open(filepath, 'r', encoding='utf-8') as file:
        text = file.read().replace('\n', '. ')
        text = text.replace('.”', '”.').replace('."', '".').replace('?”', '”?').replace('!”', '”!')
        text = text.replace('--', ' ').replace('. . .', '').replace('_', '').replace("...", "…")
        text = text.replace("\xa0", " ").replace("\x7f", "").replace("\x01", "")

    sentences = tokenize.sent_tokenize(text)
    sentences = [sentence for sentence in sentences if len(sentence) >= min_char]

    return list(sentences)

# %% [markdown]
# Let's print the sentences from one txt file.

# %%
path = "./Chekhov/Агафья.txt"
new_text = split_text(path)
for number, sent in enumerate(new_text, start=1):
  print(number, sent)
# Out:
# 1 Антон Чехов.
# 2 АГАФЬЯ.
# 3 В бытность мою в С—м уезде мне часто приходилось бывать на Дубовских огородах у огородника Саввы Стукача, или попросту Савки.
# 4 Эти огороды были моим излюбленным местом для так называемой «генеральной» рыбной ловли, когда, уходя из дому, не знаешь дня и часа, в которые вернешься, забираешь с собой все до одной рыболовные снасти и запасаешься провизией.
# 5 Собственно говоря, меня не так занимала рыбная ловля, как безмятежное шатанье, еда не вовремя, беседа с Савкой и продолжительные очные ставки с тихими летними ночами.
# 6 Савка был парень лет 25, рослый, красивый, здоровый, как кремень.
# 7 Слыл он за человека рассудительного и толкового, был грамотен, водку пил редко, но как работник этот молодой и сильный человек не стоил и гроша медного.
# 8 Рядом с силой в его крепких, как веревка, мышцах разливалась тяжелая, непобедимая лень.
# 9 Жил он, как и все на деревне, в собственной избе, пользовался наделом, но не пахал, не сеял и никаким ремеслом не занимался.
# 10 Старуха мать его побиралась под окнами, и сам он жил, как птица небесная: утром не знал, что будет есть в полдень.
# 11 Не то, чтобы у него не хватало воли, энергии или жалости к матери, а просто так, не чувствовалось охоты к труду и не сознавалась польза его… От всей фигуры так и веяло безмятежностью, врожденной, почти артистической страстью к житью зря, спустя рукава.
# 12 Когда же молодое, здоровое тело Савки физиологически потягивало к мышечной работе, то парень ненадолго весь отдавался какой-нибудь свободной, но вздорной профессии вроде точения ни к чему не нужных колышков или беганья с бабами наперегонку.
# 13 Самым любимым его положением была сосредоточенная неподвижность.
# 14 Он был в состоянии простаивать целые часы на одном месте, не шевелясь и глядя в одну точку.
# 15 Двигался же по вдохновению и то только, когда представлялся случай сделать какое-нибудь быстрое, порывистое движение: ухватить бегущую собаку за хвост, сорвать с бабы платок, перескочить широкую яму.
# 16 Само собою разумеется, что при такой скупости на движения Савка был гол как сокол и жил хуже всякого бобыля.
# 17 С течением времени должна была накопиться недоимка, и он, здоровый и молодой, был послан миром на стариковское место, в сторожа и пугало общественных огородов.
# 18 Как ни смеялись над ним по поводу его преждевременной старости, но он и в ус не дул.
# 19 Это место, тихое, удобное для неподвижного созерцания, было как раз по его натуре.. Случилось мне быть у этого самого Савки в один из хороших майских вечеров.
# 20 Помню, я лежал на рваной, затасканной полости почти у самого шалаша, от которого шел густой и душный запах сухих трав.
# 21 Подложив руки под голову, я глядел вперед себя.
# 22 У ног моих лежали деревянные вилы.
# 23 За ними черным пятном резалась в глаза собачонка Савки — Кутька, а не дальше, как сажени на две от Кутьки, земля обрывалась в крутой берег речки.
# 24 Лежа я не мог видеть реки.
# 25 Я видел только верхушки лозняка, теснившегося на этом берегу, да извилистый, словно обгрызенный край противоположного берега.
# 26 Далеко за берегом, на темном бугре, как испуганные молодые куропатки, жались друг к другу избы деревни, в которой жил мой Савка.
# 27 За бугром догорала вечерняя заря.
# 28 Осталась одна только бледно-багровая полоска, да и та стала подергиваться мелкими облачками, как уголья пеплом.. Направо от огорода, тихо пошёптывая и изредка вздрагивая от невзначай налетавшего ветра, темнела ольховая роща, налево тянулось необозримое поле.
# 29 Там, где глаз не мог уж отличить в потемках поле от неба, ярко мерцал огонек.
# 30 Поодаль от меня сидел Савка.
# 31 Поджав под себя по-турецки ноги и свесив голову, он задумчиво глядел на Кутьку.
# 32 Наши крючки с живцами давно уже стояли в реке, и нам ничего не оставалось делать, как только предаваться отдыху, который так любил никогда не утомлявшийся и вечно отдыхавший Савка.
# 33 Заря еще не совсем погасла, а летняя ночь уж охватывала своей нежащей, усыпляющей лаской природу.. Всё замирало в первом, глубоком сне, лишь какая-то не известная мне ночная птица протяжно и лениво произносила в роще длинный членораздельный звук, похожий на фразу: «Ты Ни-ки-ту видел?» и тотчас же отвечала сама себе: «Видел!
# 34 видел!
# 35 видел!».
# 36 — Отчего это нынче соловьи не поют?
# 37 — спросил я Савку.. Тот медленно повернулся ко мне.
# 38 Черты лица его были крупны, но ясны, выразительны и мягки, как у женщины.
# 39 Затем он взглянул своими кроткими, задумчивыми глазами на рощу, на лозняк, медленно вытащил из кармана дудочку, вложил ее в рот и запискал соловьихой.
# 40 И тотчас же, точно в ответ на его писканье, на противоположном берегу задергал коростель.. — Вот вам и соловей… — усмехнулся Савка.
# 41 — Дерг-дерг!
# 42 Дерг-дерг!
# 43 Словно за крючок дергает, а ведь небось тоже думает, что поет.. — Мне нравится эта птица… — сказал я.
# 44 — Ты знаешь?
# 45 Во время перелета коростель не летит, а по земле бежит.
# 46 Перелетает только через реки и моря, а то всё пешком.. — Ишь ты, собака… — пробормотал Савка, поглядев с уважением в сторону кричавшего коростеля.. Зная, каким любителем был Савка послушать, я рассказал ему всё, что знал о коростеле из охотничьих книг.
# 47 С коростеля я незаметно перешел на перелет.
# 48 Савка слушал меня внимательно, не мигая глазами, и всё время улыбался от удовольствия.. — А какой край для птиц роднее?
# 49 — спросил он.
# 50 — Наш или тамошний?.
# 51 — Конечно, наш.
# 52 Тут птица и сама родится, и детей выводит, здесь у нее родина, а туда она летит только затем, чтобы не замерзнуть.. — Любопытно!
# 53 — потянулся Савка.
# 54 — Про что ни говори, всё любопытно.
# 55 Птица таперя, человек ли… камешек ли этот взять — во всем своя умственность!..
# 56 Эх, кабы знатье, барин, что вы придете, не велел бы я нынче бабе сюда приходить… Просилась одна нынче придтить….
# 57 — Ах, сделай милость, я мешать не стану!
# 58 — сказал я.
# 59 — Я могу и в роще лечь….
# 60 — Ну, вот еще!
# 61 Не умерла б, коли завтра пришла… Ежели б она села тут да разговоры слушала, а то ведь только слюни распустит.
# 62 При ней не поговоришь толком.. — Ты Дарью ждешь?
# 63 — спросил я, помолчав.. — Нет… Нынче новая просилась… Агафья Стрельчиха….
# 64 Савка произнес это своим обычным, бесстрастным, несколько глухим голосом, точно говорил о табаке или каше, я же привскочил от удивления.
# 65 Стрельчиху Агафью я знал… Это была совсем еще молодая бабенка, лет 19—20, не далее как год тому назад вышедшая замуж за железнодорожного стрелочника, молодого и бравого парня.
# 66 Жила она на деревне, а муж ходил ночевать к ней с линии каждую ночь.. — Плохим, брат, кончатся все эти твои бабьи истории!
# 67 — вздохнул я.. — А пусть….
# 68 И, немного подумав, Савка прибавил:.
# 69 — Я говорил бабам, не слушаются… Им, дурам, и горя мало!.
# 70 Наступило молчание… Потемки, между тем, всё более сгущались, и предметы теряли свои контуры.
# 71 Полоска за бугром совсем уже потухла, а звезды становились всё ярче, лучистее… Меланхолически-однообразная трескотня кузнечиков, дерганье коростеля и крик перепела не нарушали ночной тишины, а, напротив, придавали ей еще бо́льшую монотонность.
# 72 Казалось, тихо звучали и чаровали слух не птицы, не насекомые, а звезды, глядевшие на нас с неба….
# 73 Первый нарушил молчание Савка.
# 74 Он медленно перевел глаза с черной Кутьки на меня и сказал:.
# 75 — Вам, барин, я вижу, скучно.
# 76 Давайте ужинать.. И, не дожидаясь моего согласия, он пополз на животе в шалаш, пошарил там, причем весь шалаш затрепетал, как один лист; потом он пополз назад и поставил передо мной мою водку и черепенную чашку.
# 77 В чашке были печеные яйца, ржавые лепешки на сале, куски черного хлеба и еще что-то… Мы выпили из кривого, не умевшего стоять стаканчика и принялись за еду… Серая, крупная соль, грязные, сальные лепешки, упругие, как резина, яйца, но зато как всё это вкусно!.
# 78 — Живешь бобылем, а сколько у тебя добра всякого, — сказал я, указывая на чашку.
# 79 — Где ты его берешь?.
# 80 — Бабы носят… — промычал Савка.. — За что же это они тебе носят?.
# 81 — Так… из жалости….
# 82 Не одно только меню, но и одежда Савки носила на себе следы женской «жалости».
# 83 Так, в этот вечер я заметил на нем новый гарусный поясок и ярко-пунцовую ленточку, на которой висел на грязной шее медный крестик.
# 84 Я знал о слабости прекрасного пола к Савке и знал, как он неохотно говорил о ней, а потому не продолжал своего допроса.
# 85 Да и к тому же не время было говорить… Кутька, которая терлась около нас и терпеливо ожидала подачки, вдруг наострила уши и заворчала.
# 86 Послышался отдаленный, прерывистый плеск воды.. — Кто-то бродом идет… — сказал Савка.. Минуты через три Кутька опять заворчала и издала звук, похожий на кашель.. — Цыц!
# 87 — крикнул на нее хозяин.. В потемках глухо зазвучали робкие шаги, и из рощи показался силуэт женщины.
# 88 Я узнал ее, несмотря даже на то, что было темно, — это была Агафья Стрельчиха.
# 89 Она несмело подошла к нам, остановилась и тяжело перевела дыхание.
# 90 Запыхалась она не столько от ходьбы, сколько, вероятно, от страха и неприятного чувства, испытываемого всяким при переходе в ночное время через брод.
# 91 Увидев возле шалаша вместо одного двоих, она слабо вскрикнула и отступила шаг назад.. — А… это ты!
# 92 — произнес Савка, запихивая в рот лепешку.. — Я… я-с, — забормотала она, роняя на землю узелок с чем-то и косясь на меня.
# 93 — Кланялся вам Яков и велел передать… вот тут что-то такое….
# 94 — Ну, что врать: Яков!
# 95 — усмехнулся Савка.
# 96 — Нечего врать, барин знает, зачем ты пришла!
# 97 Садись, гостьей будешь.. Агафья покосилась на меня и нерешительно села.. — А уж я думал, что ты не придешь нынче… — сказал Савка после продолжительного молчания.
# 98 — Что ж сидеть?
# 99 Или нешто дать тебе водочки выпить?.
# 100 — Выдумал!
# 101 — проговорила Агафья.
# 102 — Пьяницу какую нашел….
# 103 — А ты выпей… Жарче на душе станет… Ну!.
# 104 Савка подал Агафье кривой стаканчик.
# 105 Та медленно выпила водку, не закусила, а только громко дунула.. — Принесла что-то… — продолжал Савка, развязывая узелок и придавая своему голосу снисходительно-шутливый оттенок.
# 106 — Баба без того не может, чтоб чего не принесть.
# 107 А, пирог и картошка… Хорошо живут!
# 108 — вздохнул он, поворачиваясь ко мне лицом.
# 109 — Во всей деревне только у них еще и осталась с зимы картошка!.
# 110 Впотьмах я не видел лица Агафьи, но, по движению ее плеч и головы, мне казалось, что она не отрывала глаз с лица Савки.
# 111 Чтобы не быть третьим лицом на свидании, я решил пойти гулять и поднялся.
# 112 Но в это время в роще неожиданно соловей взял две нижние контральтовые ноты.
# 113 Через полминуты он пустил высокую, мелкую дробь и, испробовав таким образом свой голос, начал петь.
# 114 Савка вскочил и прислушался.. — Это вчерашний!
# 115 — сказал он.
# 116 — Постой же!… И, сорвавшись с места, он бесшумно побежал к роще.. — Ну, на что он тебе сдался?
# 117 — крикнул я ему вслед.
# 118 — Оставь!.
# 119 Савка махнул рукой — не кричите, мол — и исчез в потемках.
# 120 Когда хотел, Савка был прекрасным и охотником и рыболовом, но и тут его таланты тратились так же попусту, как и сила.
# 121 Для шаблона он был ленив, а всю свою охотничью страсть отдавал пустым фокусам.
# 122 Так, соловьев ловил он непременно руками, стрелял бекасинником щук, или стоит, бывало, у реки по целым часам и изо всех сил старается поймать большим крючком маленькую рыбку.. Оставшись со мной, Агафья кашлянула и провела несколько раз по лбу ладонью… От выпитой водки она уж начинала пьянеть.. — Как живешь, Агаша?
# 123 — спросил я ее после продолжительного молчания, когда уж неловко было молчать.. — Слава богу… Вы же никому не рассказывайте, барин… — прибавила она вдруг шёпотом.. — Ну, полно, — успокоил я ее.
# 124 — Какая же ты все-таки бесстрашная, Агаша… А если узнает Яков?.
# 125 — Не узнает….
# 126 — Ну, а вдруг!.
# 127 — Нет… Я раньше его дома буду.
# 128 Он теперь на линии и воротится, когда почтовый поезд проводит, а отсюда слышно, когда поезд идет….
# 129 Агафья еще раз провела рукой по лбу и посмотрела в ту сторону, куда ушел Савка.
# 130 Соловей пел.
# 131 Какая-то ночная птица низко пролетела над самой землей и, заметя нас, вздрогнула, зашуршала крыльями и полетела на ту сторону реки.. Скоро соловей умолк, но Савка не возвращался.
# 132 Агафья встала, беспокойно сделала несколько шагов и опять села.. — Да что же это он?
# 133 — не выдержала она.
# 134 — Ведь поезд не завтра придет!
# 135 Мне сейчас уходить нужно!.
# 136 — Савка!
# 137 — крикнул я.
# 138 — Савка!.
# 139 Мне не ответило даже эхо.
# 140 Агафья беспокойно задвигалась и опять встала.. — Мне уходить пора!
# 141 — проговорила она волнующимся голосом.
# 142 — Сейчас поезд придет!
# 143 Я знаю, когда поезды ходят!.
# 144 Бедная бабенка не ошиблась.
# 145 Не прошло и четверти часа, как послышался далекий шум.. Агафья остановила долгий взгляд на роще и нетерпеливо зашевелила руками.. — Ну, где же он?
# 146 — заговорила она, нервно смеясь.
# 147 — Куда же это его унесла нелегкая?
# 148 Я уйду!
# 149 Ей-богу, барин, уйду!.
# 150 Между тем шум становился всё явственней.
# 151 Можно уж было отличить стук колес от тяжелых вздохов локомотива.
# 152 Вот послышался свист, поезд глухо простучал по мосту… еще минута — и всё стихло….
# 153 — Погожу еще минутку… — вздохнула Агафья, решительно садясь.
# 154 — Так и быть, погожу!.
# 155 Наконец в потемках показался Савка.
# 156 Он бесшумно ступал босыми ногами по рыхлой, огородной земле и что-то тихо мурлыкал.. — Ведь вот счастье, скажи на милость!
# 157 — весело засмеялся он.
# 158 — Только что, это самое, значит, подошел к кусту и только что стал рукой целиться, а он и замолчал!
# 159 Ах ты, пес лысый!
# 160 Ждал, ждал, покеда опять запоет, да так и плюнул….
# 161 Савка неуклюже повалился на землю около Агафьи и, чтобы сохранить равновесие, ухватился обеими руками за ее талию.. — А ты что насупилась, словно тетка тебя родила?
# 162 — спросил он.. При всем своем мягкосердечии и простодушии Савка презирал женщин.
# 163 Он обходился с ними небрежно, свысока и даже унижался до презрительного смеха над их чувством к его же собственной особе.
# 164 Бог знает, быть может, это небрежное, презрительное обращение и было одной из причин его сильного, неотразимого обаяния на деревенских дульциней.
# 165 Он был красив и строен, — в глазах его всегда, даже при взгляде на презираемых им женщин, светилась тихая ласковость, но одними внешними качествами не объяснишь этого обаяния.
# 166 Кроме счастливой наружности и своеобразной манеры обращения, надо думать, имела влияние на женщин также еще и трогательная роль Савки как всеми признанного неудачника и несчастного изгнанника из родной избы в огороды.. — А расскажи-ка барину, зачем ты сюда пришла!
# 167 — продолжал Савка, всё еще держа Агафью за талию.
# 168 — Ну-ка, расскажи, мужнина жена!
# 169 Хо-хо… Нешто нам, брат Агаша, еще водочки выпить?.
# 170 Я поднялся и, пробираясь между грядами, пошел вдоль огорода.
# 171 Темные гряды глядели, как большие приплюснутые могилы.
# 172 От них веяло запахом вскопанной земли и нежной сыростью растений, начавших покрываться росой… Налево всё еще светился красный огонек.
# 173 Он приветливо моргал и, казалось, улыбался.. Я услышал счастливый смех.
# 174 То смеялась Агафья.. «А поезд?
# 175 — вспомнил я.
# 176 — Поезд давно уже пришел».. Подождав немного, я вернулся к шалашу.
# 177 Савка сидел неподвижно по-турецки и тихо, чуть слышно, мурлыкал какую-то песню, состоящую из одних только односложных слов, что-то вроде: «Фу ты, ну ты… я да ты…» Агафья, опьяненная водкой, презрительной лаской Савки и духотою ночи, лежала возле него на земле и судорожно прижималась лицом к его колену.
# 178 Она так далеко ушла в чувство, что и не заметила моего прихода.. — Агаша, а ведь поезд давно уж пришел!
# 179 — сказал я.. — Пора, пора тебе, — подхватил мою мысль Савка, встряхивая головой.
# 180 — Что разлеглась тут?
# 181 Ты, бесстыжая!.
# 182 Агафья встрепенулась, отняла голову от его колена, взглянула на меня и опять припала к нему.. — Давно уж пора!
# 183 — сказал я.. Агафья заворочалась и привстала на одно колено… Она страдала… Полминуты вся ее фигура, насколько я мог разглядеть сквозь потемки, выражала борьбу и колебание.
# 184 Было мгновение, когда она, будто очнувшись, вытянула корпус, чтобы подняться на ноги, но тут какая-то непобедимая и неумолимая сила толкнула ее по всему телу, и она припала к Савке.. — А ну его!
# 185 — сказала она с диким, грудным смехом, и в этом смехе слышалась безрассудная решимость, бессилие, боль.. Я тихо побрел в рощу, а оттуда спустился к реке, где стояли наши рыболовные снасти.
# 186 Река спала.
# 187 Какой-то мягкий, махровый цветок на высоком стебле нежно коснулся моей щеки, как ребенок, который хочет дать понять, что не спит.
# 188 От нечего делать я нащупал одну леску и потянул ее.
# 189 Она слабо напряглась и повисла, — ничего не поймалось… Того берега и деревни не было видно.
# 190 В одной избе мелькнул огонек, но скоро погас.
# 191 Я пошарил на берегу, нашел выемку, которую приглядел еще днем, и уселся в ней, как в кресле.
# 192 Долго я сидел… Я видел, как звезды стали туманиться и терять свою лучистость, как легким вздохом пронеслась по земле прохлада и тронула листья просыпавшихся ив….
# 193 — А-га-фья!..
# 194 — донесся из деревни чей-то глухой голос.
# 195 — Агафья!.
# 196 То вернувшийся и встревоженный муж искал по деревне свою жену.
# 197 А с огородов слышался в это время несдерживаемый смех: жена забылась, опьянела и счастием нескольких часов старалась наверстать ожидавшую ее назавтра муку.. Я уснул.. Когда я проснулся, около меня сидел Савка и слегка тряс мое плечо.
# 198 Река, роща, оба берега, зеленые и умытые, деревня и поле — всё было залито ярким утренним светом.
# 199 Сквозь тонкие стволы деревьев били в мою спину лучи только что взошедшего солнца.. — Так-то вы рыбу ловите?
# 200 — усмехнулся Савка.
# 201 — Ну, вставайте!.
# 202 Я встал, сладко потянулся, и проснувшаяся грудь моя начала жадно пить влажный, душистый воздух.. — Агаша ушла?
# 203 — спросил я.. — Вон она, — указал мне Савка в сторону, где был брод.. Я взглянул и увидел Агафью.
# 204 Приподняв платье, растрепанная, со сползшим с головы платком, она переходила реку.
# 205 Ноги ее ступали еле-еле….
# 206 — Знает кошка, чье мясо съела!
# 207 — бормотал Савка, щуря на нее глаза.
# 208 — Идет и хвост поджала… Шкодливы эти бабы, как кошки, трусливы — как зайцы… Не ушла, дура, вчера, когда говорили ей!
# 209 Теперь ей достанется, да и меня в волости… опять за баб драть будут….
# 210 Агафья ступила на берег и пошла по полю к деревне.
# 211 Сначала она шагала довольно смело, но скоро волнение и страх взяли свое: она пугливо обернулась, остановилась и перевела дух.. — То-то, что страшно!
# 212 — грустно усмехнулся Савка, глядя на ярко-зеленую полосу, которая тянулась по росистой траве вслед за Агафьей.
# 213 — Не хочется идти!
# 214 Муж-то уж целый час стоит и поджидает… Видали его?.
# 215 Савка сказал последние слова улыбаясь, а у меня похолодело под сердцем.
# 216 В деревне, около крайней избы, на дороге, стоял Яков и в упор глядел на возвращающуюся к нему жену.
# 217 Он не шевелился и был неподвижен, как столб.
# 218 Что он думал, глядя на нее?
# 219 Какие слова готовил для встречи?
# 220 Агафья постояла немного, еще раз оглянулась, точно ожидая от нас помощи, и пошла.
# 221 Никогда я еще не видал такой походки ни у пьяных, ни у трезвых.
# 222 Агафью будто корчило от взгляда мужа.
# 223 Она шла то зигзагами, то топталась на одном месте, подгибая колени и разводя руками, то пятилась назад.
# 224 Пройдя шагов сто, она оглянулась еще раз и села.. — Ты бы хоть за куст спрятался… — сказал я Савке.
# 225 — Неравно тебя муж увидит….
# 226 — Он и без того знает, от кого это Агашка идет… На огород по ночам бабы не за капустой ходят — всем известно.. Я взглянул на лицо Савки.
# 227 Оно было бледно и морщилось брезгливою жалостью, какая бывает у людей, когда они видят мучимых животных.. — Кошке смех, мышке слезы… — вздохнул он.. Агафья вдруг вскочила, мотнула головой и смелой походкой направилась к мужу.
# 228 Она, видимо, собралась с силами и решилась.

# %%
chekhov = []
for path in glob.glob('./Chekhov/*.txt'):
    chekhov += split_text(path)

dostoevsky = []
for path in glob.glob('./Dostoevsky/*.txt'):
    dostoevsky += split_text(path)

tolstoy = []
for path in glob.glob('./Tolstoy/*.txt'):
    tolstoy += split_text(path)

gogol = []
for path in glob.glob('./Gogol/*.txt'):
    gogol += split_text(path)

# %%
text_dict = {'Chekhov': chekhov, 'Dostoevsky': dostoevsky, 'Tolstoy': tolstoy, 'Gogol': gogol}

for key in text_dict.keys():
    print(key, ':', len(text_dict[key]), ' sentences')
# Out:
# Chekhov : 22729  sentences
# Dostoevsky : 118479  sentences
# Tolstoy : 92213  sentences
# Gogol : 23750  sentences

# %% [markdown]
# Each list contains 22729 to 118475 sentences. In order to have an even distribution of authors in our set, we will limit the set for each, for example, to 2750 sentences. Why this number? 2500 sentences for each author will for the training set (10000 sentences) and 250 sentences for each author will form the test set (1000 sentences).

# %% [markdown]
# We are going to use NumPy's random module because it was used by the creators of the dataset on kaggle.

# %%
# Set the random seed for reproducibility
np.random.seed(1)

# Maximum number of sentences to select from each author
max_len = 2750

# Create "names" - a list of lists of sentences for each author
names = [chekhov, dostoevsky, tolstoy, gogol]

# Create an empty list to store the combined sentences
combined = []

for author_sentences in names:
    # Randomly select up to max_len sentences without replacement
    selected_sentences = np.random.choice(author_sentences, max_len, replace = False)
    # Add the selected sentences to the combined list
    combined += list(selected_sentences)

print('Length of combo and internally shuffled list:', len(combined))
# Out:
# Length of combo and internally shuffled list: 11000

# %% [markdown]
# However, we could also use Python's built-in random module

# %%
# Set the random seed for reproducibility
random.seed(1)

# Maximum number of sentences to select from each author
max_len = 2750

# List of author-specific sentence lists
names = [chekhov, dostoevsky, tolstoy, gogol]

# Initialize an empty list to store the combined sentences
combined = []

# Iterate through each author's sentences
for author_sentences in names:
    # Randomly select max_len sentences without replacement
    selected_sentences = random.sample(author_sentences, max_len)

    # Add the selected sentences to the combined list
    combined += selected_sentences

# Print the total number of sentences in the combined list
print('Length of combined and internally shuffled list:', len(combined))
# Out:
# Length of combined and internally shuffled list: 11000

# %% [markdown]
# ## Make a list of all labels

# %% [markdown]
# At this point, it is important to indicate the labels of the authors (their names) in the same order as in the previous step, otherwise the data will simply turn out to be incorrect.

# %%
labels = ['Chekhov'] * max_len + ['Dostoevsky'] * max_len + ['Tolstoy'] * max_len +  ['Gogol'] * max_len

print('Length of marked list:', len(labels))
# Out:
# Length of marked list: 11000

# %% [markdown]
# The output of the quantity was needed for additional control over the data and their labels. Equality means that every sentence in our dataset will have a label.

# %%
len(combined) == len(labels)
# Out:
# True

# %% [markdown]
# ##Splitting the list of all sentences into a training and a testing set

# %% [markdown]
# Separate the combined list into author-specific lists

# %%
chekhov = combined[:max_len]
dostoevsky = combined[max_len:2*max_len]
tolstoy = combined[2*max_len:3*max_len]
gogol = combined[3*max_len:]

# %% [markdown]
# Let's write a function to split a list into training and test sets:

# %%
def split_train_test(data, train_size=2500, test_size=250):
    return data[:train_size], data[train_size:train_size + test_size]

# %% [markdown]
# Split each author's data

# %%
chekhov_train, chekhov_test = split_train_test(chekhov)
dostoevsky_train, dostoevsky_test = split_train_test(dostoevsky)
tolstoy_train, tolstoy_test = split_train_test(tolstoy)
gogol_train, gogol_test = split_train_test(gogol)

# %% [markdown]
# Combine training data and test data separately

# %%
train_data = chekhov_train + dostoevsky_train + tolstoy_train + gogol_train
test_data = chekhov_test + dostoevsky_test + tolstoy_test + gogol_test

# %% [markdown]
# Create labels

# %%
train_labels = (['Chekhov'] * len(chekhov_train) + ['Dostoevsky'] * len(dostoevsky_train) +
               ['Tolstoy'] * len(tolstoy_train) + ['Gogol'] * len(gogol_train))
test_labels = (['Chekhov'] * len(chekhov_test) + ['Dostoevsky'] * len(dostoevsky_test) +
              ['Tolstoy'] * len(tolstoy_test) + ['Gogol'] * len(gogol_test))

# %% [markdown]
# ## Shuffle the training and test sets

# %% [markdown]
# Shuffle training and test sets

# %%
random.seed(3)
train_zipped = list(zip(train_data, train_labels))
random.shuffle(train_zipped)
train_data, train_labels = zip(*train_zipped)

test_zipped = list(zip(test_data, test_labels))
random.shuffle(test_zipped)
test_data, test_labels = zip(*test_zipped)

# %%
train_data_2024 = pd.DataFrame()
train_data_2024['text'] = train_data
train_data_2024['author'] = train_labels

print(train_data_2024.head())
print(train_data_2024.tail())
# Out:
#                                                 text      author
# 0  Он старался не развлекаться и не портить себе ...     Tolstoy
# 1         Всегда этак у меня перед припадком бывает.     Chekhov
# 2  Катерина Николаевна тут же и.   отказала ему, ...  Dostoevsky
# 3                                    Анна Андреевна.       Gogol
# 4  — То, что я видел сейчас, хуже всякой простуды...     Chekhov
#                                                    text      author
# 9995  Он признавал себя теперь, так же как и Марью П...     Tolstoy
# 9996  Судя по выражению его морды и усов, он сам был...     Chekhov
# 9997  Он стал видеть во всем какое-то революционное ...       Gogol
# 9998            — Великий господин, ясновельможный пан!       Gogol
# 9999                                         Глава XIV.  Dostoevsky

# %% [markdown]
# # Save the shuffled sets to csv

# %%
test_data_2024 = pd.DataFrame()
test_data_2024['text'] = test_data
test_data_2024['author'] = test_labels

print(test_data_2024.head())
print(test_data_2024.tail())
# Out:
#                                                 text   author
# 0  — Это мы понимаем… Мы ведь не все отвинчиваем…...  Chekhov
# 1                                          Да что я?    Gogol
# 2  Я думаю, у меня горло замерзло от проклятого м...    Gogol
# 3  На деда, несмотря на весь страх, смех напал, к...    Gogol
# 4  Действительно, влияние товарищей оказало на не...  Tolstoy
#                                                   text   author
# 995           Он, увидевши, что нет меня, начал звать.    Gogol
# 996  Как только табун загнали, лошади собрались вок...  Tolstoy
# 997                                       Ну, да что!.  Chekhov
# 998  И он вспомнил то робкое, жалостное выражение, ...  Tolstoy
# 999    И жених и невеста были предметом общей зависти.    Gogol

# %%
test_data_2024.to_csv('test_data_2024.csv', index=False)
train_data_2024.to_csv('train_data_2024.csv', index=False)
